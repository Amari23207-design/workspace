# %% [markdown]
# # System Check

# %% [markdown]
# # What I Hope to Get Out of This Class

# %% [markdown]
# ### My Goals

# %% [markdown]
# 1. Become more confident writing and understanding code.
# 2. Learn how to organize, analyze, and interpret data.
# 3. Improve my ability to troubleshoot and fix errors in my code.
# 4. Develop programming and data skills that I can use in future classes, internships, and my career.

# %% [markdown]
# ## Image
# ![juice](prython.jpg)
